# %%
import os
import csv
import pandas as pd

# %%
os.chdir("/data/wellbeing_bids")

# %%
a = pd.read_csv("sub-2505/func/sub-2505_task-empathy_events.tsv",delimiter='\t',encoding='utf-8')
a = a.drop(a.columns[0], axis =1)
a['duration'] = 2.0
a = a.rename(columns = {'startSecs':'onset'})
cols = a.columns.tolist()
cols = cols[-2:] + cols[:-2]
a = a[cols]

# %%
func_task = ['tom']

# %%
for filename in os.listdir("."):
    for functask in func_task:
        if os.path.exists(os.path.join(filename,'func')) == True:
            a = pd.read_csv(os.path.join(filename,'func',"{}{}{}{}".format(filename, '_task-', functask, '_bold.tsv')),delimiter='\t',encoding='utf-8')
            a = a.drop(a.columns[0], axis =1)
            a['duration'] = 2.0
            a = a.rename(columns = {'startSecs':'onset'})
            cols = a.columns.tolist()
            cols = cols[-2:] + cols[:-2]
            a = a[cols]
            a = a.fillna('n/a')
            a.to_csv(os.path.join(filename,'func',"{}{}{}{}".format(filename,'_task-', functask, '_events.tsv')),
                sep = '\t', quoting=csv.QUOTE_NONE, index = False)
            print(filename, functask)

# %%
for filename in os.listdir("."):
    for functask in func_task:
        if os.path.exists(os.path.join(filename,'func')) == True:
            root_dir = './'
            dataset_json_folder = root_dir + filename + '/func/'
            dataset_json_name= dataset_json_folder + "{}{}{}{}".format(filename,'_task-',functask,'_bold.tsv')
            os.remove(dataset_json_name)
            print(filename, functask)

# %%
a = pd.read_csv("sub-2505/func/sub-2505_task-affect_events.tsv",delimiter='\t',encoding='utf-8')

# %%
a
# Out:
#     onset  duration  iTrial  iCond  isLeft  respCorrect        RT
# 0     0.0       1.0     1.0    1.0     0.0          1.0  1.005591
# 1     4.0       1.0     2.0    1.0     0.0          1.0  1.038740
# 2     6.0       1.0     3.0    1.0     0.0          1.0  1.008617
# 3     8.0       1.0     4.0    2.0     0.0          1.0  0.590883
# 4    10.0       1.0     5.0    3.0     1.0          1.0  0.666474
# 5    16.0       1.0     6.0    2.0     0.0          1.0  0.951210
# 6    18.0       1.0     7.0    2.0     1.0          1.0  0.752431
# 7    22.0       1.0     8.0    2.0     1.0          1.0  0.647139
# 8    28.0       1.0     9.0    1.0     0.0          1.0  0.615426
# 9    30.0       1.0    10.0    2.0     0.0          NaN       NaN
# 10   32.0       1.0    11.0    1.0     0.0          0.0  0.599459
# 11   34.0       1.0    12.0    2.0     1.0          1.0  0.667659
# 12   36.0       1.0    13.0    1.0     0.0          1.0  0.495500
# 13   38.0       1.0    14.0    1.0     1.0          1.0  0.538417
# 14   40.0       1.0    15.0    2.0     1.0          1.0  0.538934
# 15   42.0       1.0    16.0    2.0     0.0          1.0  0.617992
# 16   44.0       1.0    17.0    1.0     0.0          1.0  0.555838
# 17   50.0       1.0    18.0    1.0     0.0          1.0  0.680347
# 18   52.0       1.0    19.0    2.0     1.0          1.0  0.779988
# 19   56.0       1.0    20.0    1.0     0.0          1.0  0.677411
# 20   58.0       1.0    21.0    2.0     1.0          1.0  0.485421
# 21   60.0       1.0    22.0    2.0     0.0          1.0  0.540573
# 22   62.0       1.0    23.0    3.0     1.0          1.0  0.544579
# 23   64.0       1.0    24.0    2.0     1.0          1.0  1.008005
# 24   66.0       1.0    25.0    3.0     1.0          1.0  0.646105
# 25   68.0       1.0    26.0    2.0     1.0          0.0  0.466162
# 26   70.0       1.0    27.0    3.0     1.0          1.0  0.517249
# 27   74.0       1.0    28.0    2.0     0.0          1.0  0.637837
# 28   78.0       1.0    29.0    3.0     1.0          1.0  0.529114
# 29   80.0       1.0    30.0    1.0     1.0          1.0  0.726929
# ..    ...       ...     ...    ...     ...          ...       ...
# 66  236.0       1.0    67.0    1.0     0.0          1.0  0.638405
# 67  238.0       1.0    68.0    3.0     1.0          1.0  0.570120
# 68  246.0       1.0    69.0    2.0     0.0          1.0  1.134791
# 69  250.0       1.0    70.0    1.0     1.0          1.0  0.594018
# 70  254.0       1.0    71.0    2.0     1.0          1.0  0.564488
# 71  256.0       1.0    72.0    2.0     1.0          1.0  0.663255
# 72  262.0       1.0    73.0    2.0     1.0          1.0  0.542149
# 73  266.0       1.0    74.0    2.0     0.0          1.0  0.882502
# 74  268.0       1.0    75.0    1.0     0.0          1.0  0.782086
# 75  272.0       1.0    76.0    3.0     1.0          1.0  0.720449
# 76  278.0       1.0    77.0    3.0     0.0          1.0  0.977819
# 77  280.0       1.0    78.0    3.0     0.0          1.0  0.939428
# 78  282.0       1.0    79.0    2.0     1.0          1.0  0.811045
# 79  288.0       1.0    80.0    3.0     0.0          1.0  0.767065
# 80  290.0       1.0    81.0    2.0     0.0          1.0  0.747133
# 81  294.0       1.0    82.0    3.0     0.0          1.0  0.884815
# 82  300.0       1.0    83.0    2.0     1.0          1.0  0.563681
# 83  302.0       1.0    84.0    3.0     1.0          1.0  0.722647
# 84  304.0       1.0    85.0    3.0     0.0          1.0  0.757250
# 85  308.0       1.0    86.0    3.0     0.0          1.0  0.690158
# 86  310.0       1.0    87.0    1.0     1.0          1.0  1.290760
# 87  314.0       1.0    88.0    1.0     1.0          1.0  1.260503
# 88  320.0       1.0    89.0    3.0     1.0          1.0  0.589235
# 89  322.0       1.0    90.0    3.0     1.0          1.0  0.674426
# 90  324.0       1.0    91.0    2.0     0.0          1.0  0.798545
# 91  326.0       1.0    92.0    3.0     0.0          1.0  0.938059
# 92  328.0       1.0    93.0    3.0     0.0          NaN       NaN
# 93  330.0       1.0    94.0    2.0     1.0          1.0  0.933086
# 94  332.0       1.0    95.0    1.0     0.0          1.0  0.541831
# 95  334.0       1.0    96.0    3.0     1.0          1.0  0.721920
#
# [96 rows x 7 columns]

# %%
for filename in os.listdir("."):
    for functask in func_task:
        if os.path.exists(os.path.join(filename,'func')) == True:
            a = pd.read_csv(os.path.join(filename,'func',"{}{}{}{}".format(filename, '_task-', functask, '_events.tsv')),delimiter='\t',encoding='utf-8')
            a['duration'] = 14.0
            a.to_csv(os.path.join(filename,'func',"{}{}{}{}".format(filename,'_task-', functask, '_events.tsv')),
                sep = '\t', quoting=csv.QUOTE_NONE, index = False)
            print(filename, functask)
