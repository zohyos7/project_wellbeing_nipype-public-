# %%
# %matplotlib inline
from os.path import join as opj
from nipype.interfaces.io import SelectFiles, DataSink
from nipype.interfaces.spm import (OneSampleTTestDesign, EstimateModel,
                                   EstimateContrast, Threshold)
from nipype.interfaces.utility import IdentityInterface
from nipype import Workflow, Node
from nipype.interfaces.fsl import Info
from nipype.algorithms.misc import Gunzip

# %%
from nipype.interfaces.matlab import MatlabCommand
MatlabCommand.set_default_paths('/opt/spm12')

# %%
experiment_dir = '/data/wellbeing_analysis'
output_dir = 'datasink'
working_dir = 'workingdir'

# Smoothing withds used during preprocessing
fwhm = [4, 8]

# Which contrasts to use for the 2nd-level analysis
contrast_list = ['con_0001', 'con_0002', 'con_0003', 'con_0004', 'con_0005', 'con_0006', 'con_0007', 
                 'con_0008', 'con_0009', 'con_0010', 'con_0011', 'ess_0012', 'ess_0013', 'ess_0014']

# Which task to analyze 
task_list = ['affect']

mask = "/home/zohyos7/fmri/mni_icbm152_nlin_asym_09c/1mm_brainmask.nii.gz"

# %%
# Gunzip - unzip the mask image
gunzip = Node(Gunzip(in_file=mask), name="gunzip")

# OneSampleTTestDesign - creates one sample T-Test Design
onesamplettestdes = Node(OneSampleTTestDesign(),
                         name="onesampttestdes")

# EstimateModel - estimates the model
level2estimate = Node(EstimateModel(estimation_method={'Classical': 1}),
                      name="level2estimate")

# EstimateContrast - estimates group contrast
level2conestimate = Node(EstimateContrast(group_contrast=True),
                         name="level2conestimate")
cont1 = ['Group', 'T', ['mean'], [1]]
level2conestimate.inputs.contrasts = [cont1]

# Threshold - thresholds contrasts
level2thresh = Node(Threshold(contrast_index=1,
                              use_topo_fdr=True,
                              use_fwe_correction=False,
                              extent_threshold=0,
                              height_threshold=0.005,
                              height_threshold_type='p-value',
                              extent_fdr_p_threshold=0.05),
                    name="level2thresh")

# %%
# Infosource - a function free node to iterate over the list of subject names
infosource = Node(IdentityInterface(fields=['contrast_id', 'fwhm_id', 'task_name']),
                  name="infosource")
infosource.iterables = [('contrast_id', contrast_list),
                        ('fwhm_id', fwhm),
                        ('task_name', task_list)]

# SelectFiles - to grab the data (alternativ to DataGrabber)
templates = {'cons': opj(output_dir, 'antsflow', 'sub-*', 'con', 'task-{task_name}', 'fwhm-{fwhm_id}',
                         '{contrast_id}_trans.nii')}
selectfiles = Node(SelectFiles(templates,
                               base_directory=experiment_dir,
                               sort_filelist=True),
                   name="selectfiles")

# Datasink - creates output folder for important outputs
datasink = Node(DataSink(base_directory=experiment_dir,
                         container=output_dir),
                name="datasink")

# Use the following DataSink output substitutions
substitutions = [('_contrast_id_', '')]
subjFolders = [('%s_fwhm_id_%s_task_name_%s' % (con, f, task), 'task_%s/fwhm_%s/%s' % (task, f, con))
               for f in fwhm
               for con in contrast_list
               for task in task_list]
substitutions.extend(subjFolders)
datasink.inputs.substitutions = substitutions

# %%
# Initiation of the 2nd-level analysis workflow
l2analysis = Workflow(name='l2analysis')
l2analysis.base_dir = opj(experiment_dir, working_dir)

# Connect up the 2nd-level analysis components
l2analysis.connect([(infosource, selectfiles, [('contrast_id', 'contrast_id'),
                                               ('fwhm_id', 'fwhm_id'),
                                               ('task_name', 'task_name')]),
                    (selectfiles, onesamplettestdes, [('cons', 'in_files')]),
                    (gunzip, onesamplettestdes, [('out_file',
                                                  'explicit_mask_file')]),
                    (onesamplettestdes, level2estimate, [('spm_mat_file',
                                                          'spm_mat_file')]),
                    (level2estimate, level2conestimate, [('spm_mat_file',
                                                          'spm_mat_file'),
                                                         ('beta_images',
                                                          'beta_images'),
                                                         ('residual_image',
                                                          'residual_image')]),
                    (level2conestimate, level2thresh, [('spm_mat_file',
                                                        'spm_mat_file'),
                                                       ('spmT_images',
                                                        'stat_image'),
                                                       ]),
                    (level2estimate, datasink, [('mask_image',
                                                 '2ndLevel.@mask')]),
                    (level2conestimate, datasink, [('spm_mat_file',
                                                    '2ndLevel.@spm_mat'),
                                                   ('spmT_images',
                                                    '2ndLevel.@T'),
                                                   ('con_images',
                                                    '2ndLevel.@con')]),
                    (level2thresh, datasink, [('thresholded_map',
                                               '2ndLevel.@threshold')]),
                    ])

# %%
# Create 1st-level analysis output graph
l2analysis.write_graph(graph2use='colored', format='png', simple_form=True)

# Visualize the graph
from IPython.display import Image
Image(filename=opj(l2analysis.base_dir, 'l2analysis', 'graph.png'))
# Out:
# 181031-11:33:33,354 nipype.workflow INFO:
# 	 Generated workflow graph: /data/wellbeing_analysis/workingdir/l2analysis/graph.png (graph2use=colored, simple_form=True).

# %%
l2analysis.run('MultiProc', plugin_args={'n_procs': 8})
# Out:
# 181031-11:33:38,841 nipype.workflow INFO:
# 	 Workflow l2analysis settings: ['check', 'execution', 'logging', 'monitoring']
# 181031-11:33:39,38 nipype.workflow INFO:
# 	 Running in parallel.
# 181031-11:33:39,49 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 29 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 8/8.
# 181031-11:33:39,213 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0014_fwhm_id_8_task_name_affect/selectfiles".
# 181031-11:33:39,223 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0012_fwhm_id_4_task_name_affect/selectfiles".
# 181031-11:33:39,227 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:39,226 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0011_fwhm_id_8_task_name_affect/selectfiles".
#
# 181031-11:33:39,228 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0011_fwhm_id_4_task_name_affect/selectfiles".
# 181031-11:33:39,232 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181031-11:33:39,236 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:39,237 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 181031-11:33:39,271 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:39,275 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".181031-11:33:39,266 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:39,280 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:39,216 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0014_fwhm_id_4_task_name_affect/selectfiles".
#
# 181031-11:33:39,219 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0013_fwhm_id_4_task_name_affect/selectfiles".
# 181031-11:33:39,298 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181031-11:33:39,304 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181031-11:33:39,217 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0013_fwhm_id_8_task_name_affect/selectfiles".
# 181031-11:33:39,319 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181031-11:33:39,342 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:39,220 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0012_fwhm_id_8_task_name_affect/selectfiles".
# 181031-11:33:39,353 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:39,357 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181031-11:33:39,368 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:39,397 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:41,51 nipype.workflow INFO:
# 	 [Job 0] Completed (l2analysis.selectfiles).
# 181031-11:33:41,56 nipype.workflow INFO:
# 	 [Job 1] Completed (l2analysis.selectfiles).
# 181031-11:33:41,60 nipype.workflow INFO:
# 	 [Job 2] Completed (l2analysis.selectfiles).
# 181031-11:33:41,63 nipype.workflow INFO:
# 	 [Job 3] Completed (l2analysis.selectfiles).
# 181031-11:33:41,67 nipype.workflow INFO:
# 	 [Job 4] Completed (l2analysis.selectfiles).
# 181031-11:33:41,69 nipype.workflow INFO:
# 	 [Job 5] Completed (l2analysis.selectfiles).
# 181031-11:33:41,74 nipype.workflow INFO:
# 	 [Job 6] Completed (l2analysis.selectfiles).
# 181031-11:33:41,76 nipype.workflow INFO:
# 	 [Job 7] Completed (l2analysis.selectfiles).
# 181031-11:33:41,80 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 21 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 8/8.
# 181031-11:33:41,195 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0010_fwhm_id_8_task_name_affect/selectfiles".
# 181031-11:33:41,196 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0010_fwhm_id_4_task_name_affect/selectfiles".181031-11:33:41,200 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0009_fwhm_id_4_task_name_affect/selectfiles".181031-11:33:41,201 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0008_fwhm_id_8_task_name_affect/selectfiles".
# 181031-11:33:41,201 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:41,198 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0009_fwhm_id_8_task_name_affect/selectfiles".
#
#
# 181031-11:33:41,203 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0008_fwhm_id_4_task_name_affect/selectfiles".
#
# 181031-11:33:41,206 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:41,206 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:41,207 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181031-11:33:41,208 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0007_fwhm_id_8_task_name_affect/selectfiles".
#
#
# 181031-11:33:41,210 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:41,211 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 181031-11:33:41,215 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:41,216 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0007_fwhm_id_4_task_name_affect/selectfiles".
#
# 181031-11:33:41,222 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181031-11:33:41,245 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:41,247 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:41,254 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".181031-11:33:41,255 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
#
# 181031-11:33:41,268 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:41,272 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".181031-11:33:41,272 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
#
# 181031-11:33:41,284 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:43,51 nipype.workflow INFO:
# 	 [Job 8] Completed (l2analysis.selectfiles).
# 181031-11:33:43,54 nipype.workflow INFO:
# 	 [Job 9] Completed (l2analysis.selectfiles).
# 181031-11:33:43,58 nipype.workflow INFO:
# 	 [Job 10] Completed (l2analysis.selectfiles).
# 181031-11:33:43,61 nipype.workflow INFO:
# 	 [Job 11] Completed (l2analysis.selectfiles).
# 181031-11:33:43,65 nipype.workflow INFO:
# 	 [Job 12] Completed (l2analysis.selectfiles).
# 181031-11:33:43,68 nipype.workflow INFO:
# 	 [Job 13] Completed (l2analysis.selectfiles).
# 181031-11:33:43,71 nipype.workflow INFO:
# 	 [Job 14] Completed (l2analysis.selectfiles).
# 181031-11:33:43,73 nipype.workflow INFO:
# 	 [Job 15] Completed (l2analysis.selectfiles).
# 181031-11:33:43,82 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 13 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 8/8.
# 181031-11:33:43,161 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0006_fwhm_id_8_task_name_affect/selectfiles".181031-11:33:43,163 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0006_fwhm_id_4_task_name_affect/selectfiles".181031-11:33:43,164 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0005_fwhm_id_8_task_name_affect/selectfiles".
#
# 181031-11:33:43,169 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:43,169 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0004_fwhm_id_8_task_name_affect/selectfiles".
#
# 181031-11:33:43,171 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0004_fwhm_id_4_task_name_affect/selectfiles".181031-11:33:43,166 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0005_fwhm_id_4_task_name_affect/selectfiles".
# 181031-11:33:43,172 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 181031-11:33:43,177 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:43,177 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 181031-11:33:43,178 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 181031-11:33:43,182 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:43,183 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0003_fwhm_id_4_task_name_affect/selectfiles".181031-11:33:43,183 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0003_fwhm_id_8_task_name_affect/selectfiles".
#
# 181031-11:33:43,194 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
# 181031-11:33:43,195 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181031-11:33:43,212 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:43,226 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:43,234 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".181031-11:33:43,235 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
#
# 181031-11:33:43,239 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".181031-11:33:43,240 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
#
# 181031-11:33:43,251 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:43,259 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:45,53 nipype.workflow INFO:
# 	 [Job 16] Completed (l2analysis.selectfiles).
# 181031-11:33:45,55 nipype.workflow INFO:
# 	 [Job 17] Completed (l2analysis.selectfiles).
# 181031-11:33:45,57 nipype.workflow INFO:
# 	 [Job 18] Completed (l2analysis.selectfiles).
# 181031-11:33:45,59 nipype.workflow INFO:
# 	 [Job 19] Completed (l2analysis.selectfiles).
# 181031-11:33:45,60 nipype.workflow INFO:
# 	 [Job 20] Completed (l2analysis.selectfiles).
# 181031-11:33:45,62 nipype.workflow INFO:
# 	 [Job 21] Completed (l2analysis.selectfiles).
# 181031-11:33:45,64 nipype.workflow INFO:
# 	 [Job 22] Completed (l2analysis.selectfiles).
# 181031-11:33:45,66 nipype.workflow INFO:
# 	 [Job 23] Completed (l2analysis.selectfiles).
# 181031-11:33:45,70 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 5 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 8/8.
# 181031-11:33:45,152 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0002_fwhm_id_8_task_name_affect/selectfiles".181031-11:33:45,153 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0002_fwhm_id_4_task_name_affect/selectfiles".
#
# 181031-11:33:45,155 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0001_fwhm_id_8_task_name_affect/selectfiles".181031-11:33:45,158 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:45,158 nipype.workflow INFO:
# 	 [Job 28] Cached (l2analysis.gunzip).
#
# 181031-11:33:45,159 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
# 181031-11:33:45,159 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.selectfiles" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0001_fwhm_id_4_task_name_affect/selectfiles".
# 181031-11:33:45,163 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")181031-11:33:45,164 nipype.workflow INFO:
# 	 [Node] Running "selectfiles" ("nipype.interfaces.io.SelectFiles")
#
#
# 181031-11:33:45,197 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:45,206 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".181031-11:33:45,206 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
#
# 181031-11:33:45,213 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.selectfiles".
# 181031-11:33:47,55 nipype.workflow INFO:
# 	 [Job 24] Completed (l2analysis.selectfiles).
# 181031-11:33:47,57 nipype.workflow INFO:
# 	 [Job 25] Completed (l2analysis.selectfiles).
# 181031-11:33:47,58 nipype.workflow INFO:
# 	 [Job 26] Completed (l2analysis.selectfiles).
# 181031-11:33:47,60 nipype.workflow INFO:
# 	 [Job 27] Completed (l2analysis.selectfiles).
# 181031-11:33:47,63 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 28 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 8/8.
# 181031-11:33:47,153 nipype.workflow INFO:
# 	 [Job 29] Cached (l2analysis.onesampttestdes).
# 181031-11:33:47,167 nipype.workflow INFO:
# 	 [Job 34] Cached (l2analysis.onesampttestdes).
# 181031-11:33:47,183 nipype.workflow INFO:
# 	 [Job 39] Cached (l2analysis.onesampttestdes).
# 181031-11:33:47,199 nipype.workflow INFO:
# 	 [Job 44] Cached (l2analysis.onesampttestdes).
# 181031-11:33:47,218 nipype.workflow INFO:
# 	 [Job 49] Cached (l2analysis.onesampttestdes).
# 181031-11:33:47,239 nipype.workflow INFO:
# 	 [Job 54] Cached (l2analysis.onesampttestdes).
# 181031-11:33:47,254 nipype.workflow INFO:
# 	 [Job 59] Cached (l2analysis.onesampttestdes).
# 181031-11:33:47,269 nipype.workflow INFO:
# 	 [Job 64] Cached (l2analysis.onesampttestdes).
# 181031-11:33:49,160 nipype.workflow INFO:
# 	 [Job 30] Cached (l2analysis.level2estimate).
# 181031-11:33:49,164 nipype.workflow INFO:
# 	 [Job 35] Cached (l2analysis.level2estimate).
# 181031-11:33:49,167 nipype.workflow INFO:
# 	 [Job 40] Cached (l2analysis.level2estimate).
# 181031-11:33:49,170 nipype.workflow INFO:
# 	 [Job 45] Cached (l2analysis.level2estimate).
# 181031-11:33:49,173 nipype.workflow INFO:
# 	 [Job 50] Cached (l2analysis.level2estimate).
# 181031-11:33:49,177 nipype.workflow INFO:
# 	 [Job 55] Cached (l2analysis.level2estimate).
# 181031-11:33:49,180 nipype.workflow INFO:
# 	 [Job 60] Cached (l2analysis.level2estimate).
# 181031-11:33:49,183 nipype.workflow INFO:
# 	 [Job 65] Cached (l2analysis.level2estimate).
# 181031-11:33:51,142 nipype.workflow INFO:
# 	 [Job 31] Cached (l2analysis.level2conestimate).
# 181031-11:33:51,147 nipype.workflow INFO:
# 	 [Job 36] Cached (l2analysis.level2conestimate).
# 181031-11:33:51,154 nipype.workflow INFO:
# 	 [Job 41] Cached (l2analysis.level2conestimate).
# 181031-11:33:51,160 nipype.workflow INFO:
# 	 [Job 46] Cached (l2analysis.level2conestimate).
# 181031-11:33:51,166 nipype.workflow INFO:
# 	 [Job 51] Cached (l2analysis.level2conestimate).
# 181031-11:33:51,172 nipype.workflow INFO:
# 	 [Job 56] Cached (l2analysis.level2conestimate).
# 181031-11:33:51,178 nipype.workflow INFO:
# 	 [Job 61] Cached (l2analysis.level2conestimate).
# 181031-11:33:51,185 nipype.workflow INFO:
# 	 [Job 66] Cached (l2analysis.level2conestimate).
# 181031-11:33:53,139 nipype.workflow INFO:
# 	 [Job 32] Cached (l2analysis.level2thresh).
# 181031-11:33:53,143 nipype.workflow INFO:
# 	 [Job 37] Cached (l2analysis.level2thresh).
# 181031-11:33:53,149 nipype.workflow INFO:
# 	 [Job 42] Cached (l2analysis.level2thresh).
# 181031-11:33:53,154 nipype.workflow INFO:
# 	 [Job 47] Cached (l2analysis.level2thresh).
# 181031-11:33:53,160 nipype.workflow INFO:
# 	 [Job 52] Cached (l2analysis.level2thresh).
# 181031-11:33:53,168 nipype.workflow INFO:
# 	 [Job 57] Cached (l2analysis.level2thresh).
# 181031-11:33:53,173 nipype.workflow INFO:
# 	 [Job 62] Cached (l2analysis.level2thresh).
# 181031-11:33:53,180 nipype.workflow INFO:
# 	 [Job 67] Cached (l2analysis.level2thresh).
# 181031-11:33:55,152 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0014_fwhm_id_8_task_name_affect/datasink".
# 181031-11:33:55,159 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0014_fwhm_id_4_task_name_affect/datasink".
#
# 181031-11:33:55,162 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")181031-11:33:55,165 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0014_fwhm_id_8_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0014/spmT_0001_thr.nii181031-11:33:55,167 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0013_fwhm_id_8_task_name_affect/datasink".
#
# 181031-11:33:55,172 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:33:55,176 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0014_fwhm_id_4_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0014/spmT_0001_thr.nii
# 181031-11:33:55,177 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0013_fwhm_id_4_task_name_affect/datasink".
# 181031-11:33:55,179 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:33:55,183 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0013_fwhm_id_8_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0013/spmT_0001_thr.nii181031-11:33:55,184 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 181031-11:33:55,186 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0012_fwhm_id_8_task_name_affect/datasink".
# 181031-11:33:55,188 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0013_fwhm_id_4_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0013/spmT_0001_thr.nii
# 181031-11:33:55,196 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_ess_0012_fwhm_id_4_task_name_affect/datasink".
# 181031-11:33:55,198 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:33:55,203 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0012_fwhm_id_8_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0012/spmT_0001_thr.nii
# 181031-11:33:55,207 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:33:55,208 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0011_fwhm_id_8_task_name_affect/datasink".
# 181031-11:33:55,210 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0012_fwhm_id_4_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0012/spmT_0001_thr.nii
# 181031-11:33:55,216 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:33:55,219 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0011_fwhm_id_8_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0011/spmT_0001_thr.nii181031-11:33:55,218 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0011_fwhm_id_4_task_name_affect/datasink".
#
# 181031-11:33:55,227 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:33:55,230 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0011_fwhm_id_4_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0011/spmT_0001_thr.nii
# 181031-11:33:55,355 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0014_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0014/SPM.mat
# 181031-11:33:55,359 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0014_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0014/spmT_0001.nii
# 181031-11:33:55,360 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0014_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0014/SPM.mat181031-11:33:55,368 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0013_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0013/SPM.mat
# 181031-11:33:55,371 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0013_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0013/spmT_0001.nii
#
# 181031-11:33:55,375 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0014_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0014/spmT_0001.nii181031-11:33:55,375 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0012_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0012/SPM.mat181031-11:33:55,376 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0013_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0013/SPM.mat
#
#
# 181031-11:33:55,377 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0013_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0013/spmT_0001.nii181031-11:33:55,378 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0012_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0012/spmT_0001.nii
#
# 181031-11:33:55,390 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0012_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0012/SPM.mat
# 181031-11:33:55,395 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0012_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0012/spmT_0001.nii181031-11:33:55,395 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0011_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0011/SPM.mat
#
# 181031-11:33:55,398 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0011_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0011/spmT_0001.nii
# 181031-11:33:55,415 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0011_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0011/SPM.mat
# 181031-11:33:55,417 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0011_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0011/spmT_0001.nii
# 181031-11:33:55,531 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0014_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0014/con_0001.nii181031-11:33:55,532 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0013_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0013/con_0001.nii
#
# 181031-11:33:55,540 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0012_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0012/con_0001.nii181031-11:33:55,543 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0013_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0013/con_0001.nii
#
# 181031-11:33:55,546 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0014_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/ess_0014/con_0001.nii
# 181031-11:33:55,554 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_ess_0012_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/ess_0012/con_0001.nii
# 181031-11:33:55,557 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0011_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0011/con_0001.nii
# 181031-11:33:55,578 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0011_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0011/con_0001.nii
# 181031-11:33:55,705 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_ess_0013_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/ess_0013/mask.img
# 181031-11:33:55,707 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_ess_0012_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/ess_0012/mask.img
# 181031-11:33:55,711 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:33:55,712 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:33:55,713 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_ess_0014_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/ess_0014/mask.img
# 181031-11:33:55,717 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_ess_0014_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/ess_0014/mask.img181031-11:33:55,717 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_ess_0013_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/ess_0013/mask.img181031-11:33:55,719 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
#
#
# 181031-11:33:55,721 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0011_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0011/mask.img181031-11:33:55,722 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_ess_0012_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/ess_0012/mask.img
#
# 181031-11:33:55,724 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:33:55,725 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:33:55,727 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".181031-11:33:55,727 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
#
# 181031-11:33:55,740 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0011_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0011/mask.img
# 181031-11:33:55,745 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:33:57,66 nipype.workflow INFO:
# 	 [Job 33] Completed (l2analysis.datasink).
# 181031-11:33:57,69 nipype.workflow INFO:
# 	 [Job 38] Completed (l2analysis.datasink).
# 181031-11:33:57,72 nipype.workflow INFO:
# 	 [Job 43] Completed (l2analysis.datasink).
# 181031-11:33:57,75 nipype.workflow INFO:
# 	 [Job 48] Completed (l2analysis.datasink).
# 181031-11:33:57,78 nipype.workflow INFO:
# 	 [Job 53] Completed (l2analysis.datasink).
# 181031-11:33:57,81 nipype.workflow INFO:
# 	 [Job 58] Completed (l2analysis.datasink).
# 181031-11:33:57,83 nipype.workflow INFO:
# 	 [Job 63] Completed (l2analysis.datasink).
# 181031-11:33:57,86 nipype.workflow INFO:
# 	 [Job 68] Completed (l2analysis.datasink).
# 181031-11:33:57,91 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 20 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 8/8.
# 181031-11:33:57,187 nipype.workflow INFO:
# 	 [Job 69] Cached (l2analysis.onesampttestdes).
# 181031-11:33:57,203 nipype.workflow INFO:
# 	 [Job 74] Cached (l2analysis.onesampttestdes).
# 181031-11:33:57,219 nipype.workflow INFO:
# 	 [Job 79] Cached (l2analysis.onesampttestdes).
# 181031-11:33:57,235 nipype.workflow INFO:
# 	 [Job 84] Cached (l2analysis.onesampttestdes).
# 181031-11:33:57,250 nipype.workflow INFO:
# 	 [Job 89] Cached (l2analysis.onesampttestdes).
# 181031-11:33:57,266 nipype.workflow INFO:
# 	 [Job 94] Cached (l2analysis.onesampttestdes).
# 181031-11:33:57,282 nipype.workflow INFO:
# 	 [Job 99] Cached (l2analysis.onesampttestdes).
# 181031-11:33:57,297 nipype.workflow INFO:
# 	 [Job 104] Cached (l2analysis.onesampttestdes).
# 181031-11:33:59,157 nipype.workflow INFO:
# 	 [Job 70] Cached (l2analysis.level2estimate).
# 181031-11:33:59,162 nipype.workflow INFO:
# 	 [Job 75] Cached (l2analysis.level2estimate).
# 181031-11:33:59,168 nipype.workflow INFO:
# 	 [Job 80] Cached (l2analysis.level2estimate).
# 181031-11:33:59,173 nipype.workflow INFO:
# 	 [Job 85] Cached (l2analysis.level2estimate).
# 181031-11:33:59,179 nipype.workflow INFO:
# 	 [Job 90] Cached (l2analysis.level2estimate).
# 181031-11:33:59,184 nipype.workflow INFO:
# 	 [Job 95] Cached (l2analysis.level2estimate).
# 181031-11:33:59,189 nipype.workflow INFO:
# 	 [Job 100] Cached (l2analysis.level2estimate).
# 181031-11:33:59,194 nipype.workflow INFO:
# 	 [Job 105] Cached (l2analysis.level2estimate).
# 181031-11:34:01,161 nipype.workflow INFO:
# 	 [Job 71] Cached (l2analysis.level2conestimate).
# 181031-11:34:01,168 nipype.workflow INFO:
# 	 [Job 76] Cached (l2analysis.level2conestimate).
# 181031-11:34:01,174 nipype.workflow INFO:
# 	 [Job 81] Cached (l2analysis.level2conestimate).
# 181031-11:34:01,180 nipype.workflow INFO:
# 	 [Job 86] Cached (l2analysis.level2conestimate).
# 181031-11:34:01,186 nipype.workflow INFO:
# 	 [Job 91] Cached (l2analysis.level2conestimate).
# 181031-11:34:01,192 nipype.workflow INFO:
# 	 [Job 96] Cached (l2analysis.level2conestimate).
# 181031-11:34:01,198 nipype.workflow INFO:
# 	 [Job 101] Cached (l2analysis.level2conestimate).
# 181031-11:34:01,204 nipype.workflow INFO:
# 	 [Job 106] Cached (l2analysis.level2conestimate).
# 181031-11:34:03,159 nipype.workflow INFO:
# 	 [Job 72] Cached (l2analysis.level2thresh).
# 181031-11:34:03,163 nipype.workflow INFO:
# 	 [Job 77] Cached (l2analysis.level2thresh).
# 181031-11:34:03,171 nipype.workflow INFO:
# 	 [Job 82] Cached (l2analysis.level2thresh).
# 181031-11:34:03,175 nipype.workflow INFO:
# 	 [Job 87] Cached (l2analysis.level2thresh).
# 181031-11:34:03,180 nipype.workflow INFO:
# 	 [Job 92] Cached (l2analysis.level2thresh).
# 181031-11:34:03,185 nipype.workflow INFO:
# 	 [Job 97] Cached (l2analysis.level2thresh).
# 181031-11:34:03,190 nipype.workflow INFO:
# 	 [Job 102] Cached (l2analysis.level2thresh).
# 181031-11:34:03,194 nipype.workflow INFO:
# 	 [Job 107] Cached (l2analysis.level2thresh).
# 181031-11:34:05,168 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0010_fwhm_id_8_task_name_affect/datasink".
# 181031-11:34:05,176 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0010_fwhm_id_4_task_name_affect/datasink".
# 181031-11:34:05,178 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:34:05,181 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0010_fwhm_id_8_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0010/spmT_0001_thr.nii
# 181031-11:34:05,184 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:34:05,186 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0009_fwhm_id_8_task_name_affect/datasink".
# 181031-11:34:05,188 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0010_fwhm_id_4_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0010/spmT_0001_thr.nii
# 181031-11:34:05,198 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0009_fwhm_id_4_task_name_affect/datasink".181031-11:34:05,198 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:34:05,203 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0009_fwhm_id_8_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0009/spmT_0001_thr.nii
#
# 181031-11:34:05,212 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0008_fwhm_id_8_task_name_affect/datasink".
# 181031-11:34:05,226 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")181031-11:34:05,227 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
# 181031-11:34:05,231 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0008_fwhm_id_4_task_name_affect/datasink".181031-11:34:05,231 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0009_fwhm_id_4_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0009/spmT_0001_thr.nii
# 181031-11:34:05,231 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0008_fwhm_id_8_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0008/spmT_0001_thr.nii
#
# 181031-11:34:05,244 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")181031-11:34:05,244 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0007_fwhm_id_8_task_name_affect/datasink".
#
# 181031-11:34:05,249 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0008_fwhm_id_4_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0008/spmT_0001_thr.nii
# 181031-11:34:05,259 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0007_fwhm_id_4_task_name_affect/datasink".
# 181031-11:34:05,260 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:34:05,271 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_8_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0007/spmT_0001_thr.nii
# 181031-11:34:05,275 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:34:05,279 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_4_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0007/spmT_0001_thr.nii
# 181031-11:34:05,350 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0010_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0010/SPM.mat
# 181031-11:34:05,353 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0010_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0010/spmT_0001.nii
# 181031-11:34:05,354 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0010_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0010/SPM.mat
# 181031-11:34:05,357 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0010_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0010/spmT_0001.nii
# 181031-11:34:05,371 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0009_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0009/SPM.mat
# 181031-11:34:05,378 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0009_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0009/spmT_0001.nii
# 181031-11:34:05,402 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0009_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0009/SPM.mat
# 181031-11:34:05,405 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0009_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0009/spmT_0001.nii
# 181031-11:34:05,416 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0008_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0008/SPM.mat
# 181031-11:34:05,418 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0008_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0008/spmT_0001.nii
# 181031-11:34:05,438 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0007/SPM.mat
# 181031-11:34:05,441 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0007/spmT_0001.nii
# 181031-11:34:05,442 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0008_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0008/SPM.mat
# 181031-11:34:05,445 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0008_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0008/spmT_0001.nii
# 181031-11:34:05,451 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0007/SPM.mat
# 181031-11:34:05,454 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0007/spmT_0001.nii
# 181031-11:34:05,519 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0010_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0010/con_0001.nii
# 181031-11:34:05,538 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0010_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0010/con_0001.nii
# 181031-11:34:05,565 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0009_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0009/con_0001.nii
# 181031-11:34:05,591 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0009_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0009/con_0001.nii
# 181031-11:34:05,596 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0008_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0008/con_0001.nii
# 181031-11:34:05,605 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0007/con_0001.nii
# 181031-11:34:05,611 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0008_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0008/con_0001.nii
# 181031-11:34:05,619 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0007_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0007/con_0001.nii
# 181031-11:34:05,689 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0010_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0010/mask.img
# 181031-11:34:05,696 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:05,718 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0010_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0010/mask.img
# 181031-11:34:05,724 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:05,731 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0009_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0009/mask.img
# 181031-11:34:05,738 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:05,769 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0007_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0007/mask.img
# 181031-11:34:05,775 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:05,776 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0008_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0008/mask.img
# 181031-11:34:05,782 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".181031-11:34:05,782 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0009_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0009/mask.img
#
# 181031-11:34:05,788 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".181031-11:34:05,789 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0007_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0007/mask.img
#
# 181031-11:34:05,795 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".181031-11:34:05,796 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0008_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0008/mask.img
#
# 181031-11:34:05,802 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:07,74 nipype.workflow INFO:
# 	 [Job 73] Completed (l2analysis.datasink).
# 181031-11:34:07,77 nipype.workflow INFO:
# 	 [Job 78] Completed (l2analysis.datasink).
# 181031-11:34:07,80 nipype.workflow INFO:
# 	 [Job 83] Completed (l2analysis.datasink).
# 181031-11:34:07,82 nipype.workflow INFO:
# 	 [Job 88] Completed (l2analysis.datasink).
# 181031-11:34:07,84 nipype.workflow INFO:
# 	 [Job 93] Completed (l2analysis.datasink).
# 181031-11:34:07,87 nipype.workflow INFO:
# 	 [Job 98] Completed (l2analysis.datasink).
# 181031-11:34:07,89 nipype.workflow INFO:
# 	 [Job 103] Completed (l2analysis.datasink).
# 181031-11:34:07,91 nipype.workflow INFO:
# 	 [Job 108] Completed (l2analysis.datasink).
# 181031-11:34:07,95 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 12 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 8/8.
# 181031-11:34:07,205 nipype.workflow INFO:
# 	 [Job 109] Cached (l2analysis.onesampttestdes).
# 181031-11:34:07,221 nipype.workflow INFO:
# 	 [Job 114] Cached (l2analysis.onesampttestdes).
# 181031-11:34:07,237 nipype.workflow INFO:
# 	 [Job 119] Cached (l2analysis.onesampttestdes).
# 181031-11:34:07,253 nipype.workflow INFO:
# 	 [Job 124] Cached (l2analysis.onesampttestdes).
# 181031-11:34:07,269 nipype.workflow INFO:
# 	 [Job 129] Cached (l2analysis.onesampttestdes).
# 181031-11:34:07,286 nipype.workflow INFO:
# ...
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0004_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0004/SPM.mat181031-11:34:15,408 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0004_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0004/SPM.mat
#
# 181031-11:34:15,409 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0004_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0004/spmT_0001.nii
#
# 181031-11:34:15,410 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0006_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0006/spmT_0001.nii181031-11:34:15,411 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0004_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0004/spmT_0001.nii
#
# 181031-11:34:15,443 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0003_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0003/SPM.mat
# 181031-11:34:15,445 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0003_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0003/spmT_0001.nii
# 181031-11:34:15,462 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0003_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0003/SPM.mat
# 181031-11:34:15,466 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0003_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0003/spmT_0001.nii
# 181031-11:34:15,549 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0006_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0006/con_0001.nii
# 181031-11:34:15,566 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0005_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0005/con_0001.nii
# 181031-11:34:15,569 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0004_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0004/con_0001.nii
# 181031-11:34:15,572 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0005_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0005/con_0001.nii181031-11:34:15,573 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0004_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0004/con_0001.nii
#
# 181031-11:34:15,584 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0006_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0006/con_0001.nii
# 181031-11:34:15,604 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0003_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0003/con_0001.nii
# 181031-11:34:15,630 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0003_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0003/con_0001.nii
# 181031-11:34:15,714 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0006_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0006/mask.img
# 181031-11:34:15,719 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:15,728 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0005_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0005/mask.img
# 181031-11:34:15,730 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0004_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0004/mask.img
# 181031-11:34:15,734 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".181031-11:34:15,734 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0005_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0005/mask.img
#
# 181031-11:34:15,735 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:15,740 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:15,752 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0006_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0006/mask.img
# 181031-11:34:15,753 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0004_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0004/mask.img
# 181031-11:34:15,758 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:15,761 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:15,766 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0003_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0003/mask.img
# 181031-11:34:15,771 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:15,798 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0003_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0003/mask.img
# 181031-11:34:15,804 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:17,84 nipype.workflow INFO:
# 	 [Job 113] Completed (l2analysis.datasink).
# 181031-11:34:17,87 nipype.workflow INFO:
# 	 [Job 118] Completed (l2analysis.datasink).
# 181031-11:34:17,90 nipype.workflow INFO:
# 	 [Job 123] Completed (l2analysis.datasink).
# 181031-11:34:17,93 nipype.workflow INFO:
# 	 [Job 128] Completed (l2analysis.datasink).
# 181031-11:34:17,95 nipype.workflow INFO:
# 	 [Job 133] Completed (l2analysis.datasink).
# 181031-11:34:17,97 nipype.workflow INFO:
# 	 [Job 138] Completed (l2analysis.datasink).
# 181031-11:34:17,99 nipype.workflow INFO:
# 	 [Job 143] Completed (l2analysis.datasink).
# 181031-11:34:17,101 nipype.workflow INFO:
# 	 [Job 148] Completed (l2analysis.datasink).
# 181031-11:34:17,104 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 4 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 8/8.
# 181031-11:34:17,221 nipype.workflow INFO:
# 	 [Job 149] Cached (l2analysis.onesampttestdes).
# 181031-11:34:17,239 nipype.workflow INFO:
# 	 [Job 154] Cached (l2analysis.onesampttestdes).
# 181031-11:34:17,255 nipype.workflow INFO:
# 	 [Job 159] Cached (l2analysis.onesampttestdes).
# 181031-11:34:17,271 nipype.workflow INFO:
# 	 [Job 164] Cached (l2analysis.onesampttestdes).
# 181031-11:34:19,189 nipype.workflow INFO:
# 	 [Job 150] Cached (l2analysis.level2estimate).
# 181031-11:34:19,195 nipype.workflow INFO:
# 	 [Job 155] Cached (l2analysis.level2estimate).
# 181031-11:34:19,200 nipype.workflow INFO:
# 	 [Job 160] Cached (l2analysis.level2estimate).
# 181031-11:34:19,205 nipype.workflow INFO:
# 	 [Job 165] Cached (l2analysis.level2estimate).
# 181031-11:34:21,195 nipype.workflow INFO:
# 	 [Job 151] Cached (l2analysis.level2conestimate).
# 181031-11:34:21,201 nipype.workflow INFO:
# 	 [Job 156] Cached (l2analysis.level2conestimate).
# 181031-11:34:21,207 nipype.workflow INFO:
# 	 [Job 161] Cached (l2analysis.level2conestimate).
# 181031-11:34:21,213 nipype.workflow INFO:
# 	 [Job 166] Cached (l2analysis.level2conestimate).
# 181031-11:34:23,181 nipype.workflow INFO:
# 	 [Job 152] Cached (l2analysis.level2thresh).
# 181031-11:34:23,185 nipype.workflow INFO:
# 	 [Job 157] Cached (l2analysis.level2thresh).
# 181031-11:34:23,189 nipype.workflow INFO:
# 	 [Job 162] Cached (l2analysis.level2thresh).
# 181031-11:34:23,193 nipype.workflow INFO:
# 	 [Job 167] Cached (l2analysis.level2thresh).
# 181031-11:34:25,186 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0002_fwhm_id_8_task_name_affect/datasink".
# 181031-11:34:25,198 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0002_fwhm_id_4_task_name_affect/datasink".
# 181031-11:34:25,205 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0001_fwhm_id_8_task_name_affect/datasink".
# 181031-11:34:25,210 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:34:25,212 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")181031-11:34:25,213 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_8_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0002/spmT_0001_thr.nii181031-11:34:25,212 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
#
#
# 181031-11:34:25,216 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_4_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0002/spmT_0001_thr.nii181031-11:34:25,216 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_8_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0001/spmT_0001_thr.nii
#
# 181031-11:34:25,218 nipype.workflow INFO:
# 	 [Node] Setting-up "l2analysis.datasink" in "/data/wellbeing_analysis/workingdir/l2analysis/_contrast_id_con_0001_fwhm_id_4_task_name_affect/datasink".
# 181031-11:34:25,230 nipype.workflow INFO:
# 	 [Node] Running "datasink" ("nipype.interfaces.io.DataSink")
# 181031-11:34:25,234 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_4_task_name_affect/spmT_0001_thr.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0001/spmT_0001_thr.nii
# 181031-11:34:25,377 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0002/SPM.mat181031-11:34:25,384 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_8_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0001/SPM.mat
#
# 181031-11:34:25,382 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0002/SPM.mat181031-11:34:25,386 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0002/spmT_0001.nii181031-11:34:25,387 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_8_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0001/spmT_0001.nii
#
#
# 181031-11:34:25,394 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0002/spmT_0001.nii
# 181031-11:34:25,402 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_4_task_name_affect/SPM.mat -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0001/SPM.mat
# 181031-11:34:25,405 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_4_task_name_affect/spmT_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0001/spmT_0001.nii
# 181031-11:34:25,548 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0002/con_0001.nii
# 181031-11:34:25,554 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_8_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_8/con_0001/con_0001.nii
# 181031-11:34:25,561 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0002_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0002/con_0001.nii
# 181031-11:34:25,570 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/_contrast_id_con_0001_fwhm_id_4_task_name_affect/con_0001.nii -> /data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0001/con_0001.nii
# 181031-11:34:25,709 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0002_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0002/mask.img
# 181031-11:34:25,715 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:25,721 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0001_fwhm_id_8_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_8/con_0001/mask.img
# 181031-11:34:25,726 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0002_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0002/mask.img
# 181031-11:34:25,730 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".181031-11:34:25,731 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
#
# 181031-11:34:25,735 nipype.interface INFO:
# 	 sub: /data/wellbeing_analysis/datasink/2ndLevel/img/_contrast_id_con_0001_fwhm_id_4_task_name_affect/mask.nii -> /data/wellbeing_analysis/datasink/2ndLevel/img/task_affect/fwhm_4/con_0001/mask.img
# 181031-11:34:25,741 nipype.workflow INFO:
# 	 [Node] Finished "l2analysis.datasink".
# 181031-11:34:27,93 nipype.workflow INFO:
# 	 [Job 153] Completed (l2analysis.datasink).
# 181031-11:34:27,96 nipype.workflow INFO:
# 	 [Job 158] Completed (l2analysis.datasink).
# 181031-11:34:27,99 nipype.workflow INFO:
# 	 [Job 163] Completed (l2analysis.datasink).
# 181031-11:34:27,103 nipype.workflow INFO:
# 	 [Job 168] Completed (l2analysis.datasink).
# 181031-11:34:27,109 nipype.workflow INFO:
# 	 [MultiProc] Running 0 tasks, and 0 jobs ready. Free memory (GB): 113.22/113.22, Free processors: 8/8.
