# %%
from nilearn.plotting import plot_stat_map
# %matplotlib inline
anatimg = '/home/zohyos7/fmri/mni_icbm152_nlin_asym_09c/1mm_T1.nii.gz'

# %% [markdown]
# # 2nd level analysis
# ## one-sample ttest
#
# ### TOM task : belief > photo contrast

# %%
plot_stat_map(
    '/data/wellbeing_analysis/datasink/2ndLevel/task_tom/fwhm_4/con_0004/spmT_0001_thr.nii', title='ants fwhm=4', dim=1,
    bg_img=anatimg, threshold=2, vmax=8, display_mode='ortho', cut_coords=(3, 6, 56), cmap='viridis');

# %%
plot_stat_map(
    '/data/wellbeing_analysis/datasink/2ndLevel/task_tom/fwhm_4/con_0004/spmT_0001_thr.nii', title='ants fwhm=4', dim=1,
    bg_img=anatimg, threshold=2, vmax=8, display_mode='x', cut_coords=(-2, 50), cmap='viridis');

# %% [markdown]
# ## AFFECT task : Negative > Neutral contrast

# %%
plot_stat_map(
    '/data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0008/spmT_0001_thr.nii', title='ants fwhm=4', dim = 1,
    bg_img=anatimg, threshold=1, vmax=8, display_mode='ortho', cut_coords=(-18, 36, 0), cmap = 'viridis');

# %%
plot_stat_map(
    '/data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0008/spmT_0001_thr.nii', title='ants fwhm=4', dim = 1,
    bg_img=anatimg, threshold=2, vmax=8, display_mode='y', cut_coords=(-22, -18, 36), cmap = 'viridis');

# %% [markdown]
# ## two-sample ttest

# %% [markdown]
# ## TOM task : belief > photo contrast, Democrats > Republican

# %%
plot_stat_map(
    '/data/wellbeing_analysis/datasink/two_sample/task_tom/con04/spmT_0004.nii', title='fwhm8', dim=1,
    bg_img=anatimg, threshold=2.5, vmax=8, display_mode='ortho', cut_coords=(3, -22, 0), cmap='viridis');

# %% [markdown]
# ## AFFECT task : Negative > Neutral contrast, Republican > Democrats

# %%
plot_stat_map(
    '/data/wellbeing_analysis/datasink/two_sample/task_affect/con08/spmT_0003.nii', title='fwhm8', dim=1,
    bg_img=anatimg, threshold=2.5, vmax=8, display_mode='ortho', cut_coords=(3, -30, 0), cmap='viridis');

# %%
from __future__ import print_function
from ipywidgets import interact, interactive, fixed, interact_manual
import ipywidgets as widgets

# %%
from nilearn import plotting
plotting.plot_img('/data/wellbeing_analysis/datasink/antsflow/sub-2542/con/task-affect/fwhm-8/con_0001_trans.nii', cut_coords=(20, -10, 36))

# %%
from nilearn import plotting
plotting.plot_img('/data/wellbeing_analysis/datasink/2ndLevel/task_affect/fwhm_4/con_0001/mask.nii', cut_coords=(20, -10, 36))
